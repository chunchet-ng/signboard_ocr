# %% [markdown]
# # 1. Setup on Google Colab

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive

drive.mount("/content/drive/")

# %% [markdown]
# ## Git clone the repo

# %%
# %cd "/content/drive/My Drive"
# !git clone https://github.com/chunchet-ng/signboard_ocr.git

# %cd "/content/drive/My Drive/signboard_ocr"
# %mv "ArT" "../ArT"

# %% [markdown]
# ## Create necessary folders

# %%
# !mkdir -p "/content/drive/My Drive/Colab Notebooks/Chapter 6"

# %mv "Detection_Evaluation" "/content/drive/My Drive/Colab Notebooks/Chapter 6/Detection_Evaluation"
# %mv "Recognition_Evaluation" "/content/drive/My Drive/Colab Notebooks/Chapter 6/Recognition_Evaluation"
# %mv "License_Plate_Recognition" "/content/drive/My Drive/Colab Notebooks/Chapter 6/Signboard_OCR"
